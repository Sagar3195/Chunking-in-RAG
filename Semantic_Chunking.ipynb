# %% [markdown]
# #### Semantic Chunking for RAG
#  - Semantic Chunking considers the relationships within the text. It divides the text into meaningful, semantically complete chunks

# %%
# !pip install langchain langchain_community langchain_groq langchain_huggingface sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 4.3 MB/s eta 0:00:00
# ...

# %%
#Download the data
# !wget "https://arxiv.org/pdf/1810.04805.pdf"
# Out:
# --2025-08-18 07:40:51--  https://arxiv.org/pdf/1810.04805.pdf
# Resolving arxiv.org (arxiv.org)... 151.101.131.42, 151.101.195.42, 151.101.67.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.131.42|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /pdf/1810.04805 [following]
# --2025-08-18 07:40:51--  https://arxiv.org/pdf/1810.04805
# Reusing existing connection to arxiv.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 775166 (757K) [application/pdf]
# Saving to: ‘1810.04805.pdf’
#
# 1810.04805.pdf      100%[===================>] 757.00K  --.-KB/s    in 0.06s
#
# 2025-08-18 07:40:52 (12.8 MB/s) - ‘1810.04805.pdf’ saved [775166/775166]

# %%
# !pip install langchain_chroma chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 80.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 14.7 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

#Load the Document
loader = PyPDFLoader("1810.04805.pdf")
documents = loader.load()

# %%
print(len(documents))
# Out:
# 16

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 0, length_function =len, is_separator_regex=False)

# %%
naive_chunks = text_splitter.split_documents(documents)
for chunk in naive_chunks[10:15]:
  print(chunk.page_content + "\n")
# Out:
# BERT BERT
# E[CLS] E1  E[SEP]... EN E1’ ... EM’
# C
#  T1
#  T[SEP]...
#  TN
#  T1’ ...
#  TM’
# [CLS] Tok 1  [SEP]... Tok N Tok 1 ... TokM
# Question Paragraph
# Start/End Span
# BERT
# E[CLS] E1  E[SEP]... EN E1’ ... EM’
# C
#  T1
#  T[SEP]...
#  TN
#  T1’ ...
#  TM’
# [CLS] Tok 1  [SEP]... Tok N Tok 1 ... TokM
# Masked Sentence A Masked Sentence B
# Pre-training Fine-Tuning
# NSP Mask LM Mask LM
# Unlabeled Sentence A and B Pair
# SQuAD
# Question Answer Pair
# NERMNLI
# Figure 1: Overall pre-training and ﬁne-tuning procedures for BERT. Apart from output layers, the same architec-
# tures are used in both pre-training and ﬁne-tuning. The same pre-trained model parameters are used to initialize
# models for different down-stream tasks. During ﬁne-tuning, all parameters are ﬁne-tuned. [CLS] is a special
# symbol added in front of every input example, and [SEP] is a special separator token (e.g. separating ques-
# tions/answers).
# ing and auto-encoder objectives have been used
# ...

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
embed_model = HuggingFaceEmbeddings(model_name="BAAI/bge-base-en-v1.5")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# ...

# %%
from google.colab import userdata
groq_api_key = userdata.get("GROQ_API_KEY")

# %%
#LLM
from langchain_groq import ChatGroq


llm = ChatGroq(model = "openai/gpt-oss-20b", api_key = groq_api_key)

# %%
# !pip install langchain_experimental
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 3.8 MB/s eta 0:00:00
# ...

# %%
#Perform Semantic Chunker
## https://python.langchain.com/docs/how_to/semantic-chunker/
from langchain_experimental.text_splitter import SemanticChunker

semantic_chunker = SemanticChunker(embed_model, breakpoint_threshold_type="percentile")

# %%
semantic_chunks = semantic_chunker.create_documents([d.page_content for d in documents])

# %%
len(semantic_chunks)
# Out:
# 56

# %%
from langchain_chroma import Chroma

semantic_chunk_vectorstore = Chroma.from_documents(semantic_chunks, embed_model)

# %%
#Retriever
semantic_chunk_retriever = semantic_chunk_vectorstore.as_retriever(search_kwargs = {"k":1})

# %%
from langchain_core.prompts import ChatPromptTemplate

rag_template = """\
Use the following context to answer the user's query. If you cannot answer, please respond with 'I don't know'.

User's Query:
{question}

Context:
{context}
"""

rag_prompt = ChatPromptTemplate.from_template(rag_template)

# %%
#RAG Pipeline

from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

semantic_rag_chain = (
    {"context": semantic_chunk_retriever, "question": RunnablePassthrough()}
    | rag_prompt
    | llm
    | StrOutputParser()
)

# %%
#Ask Question
response = semantic_rag_chain.invoke("Describe the Feature-based Approach with BERT?")
print(response)
# Out:
# **Feature‑Based Approach with BERT**
#
# The feature‑based approach treats BERT as a *feature extractor* rather than a model that is fine‑tuned end‑to‑end.
# Key points from the paper (Section 6, Table 7):
#
# | Step | What is done | Why |
# |------|-------------|-----|
# | **1. Run BERT** | Pass the input sentence through a *pre‑trained* BERT model (BERT‑BASE or BERT‑LARGE). | BERT’s deep transformer layers produce rich contextual embeddings for every token. |
# | **2. Extract activations** | Take the hidden‑state activations from one or more layers (e.g., the top four hidden layers) without updating any of BERT’s parameters. | Keeps the large, unsupervised knowledge learned during pre‑training intact; avoids expensive fine‑tuning. |
# ...

# %%
semantic_rag_chain.invoke("What is SQuADv2.0?")
# Out:
# 'SQuAD\u202fv2.0 (the Stanford Question‑Answering Dataset version\u202f2.0) is an expanded, publicly available benchmark for machine‑reading comprehension. It builds on the original SQuAD (v1.1) by adding a large set of questions that cannot be answered from the given context paragraph. Each example in SQuAD\u202fv2.0 contains:\n\n1. **A paragraph of text** (the “context”).\n2. **A question** about that paragraph.\n3. **An answer** that is a span of text from the paragraph, **or** a label indicating that the question is *unanswerable* given the paragraph.\n\nThe dataset therefore tests a model’s ability to both extract answers and to correctly decide when no answer exists. It is widely used to evaluate and compare the performance of natural‑language‑processing systems on open‑domain question answering.'

# %%
semantic_rag_chain.invoke("What is the purpose of Ablation Studies?")
# Out:
# 'Ablation studies are systematic experiments in which one or more components, hyper‑parameters, or design choices of a model are removed, changed, or varied in isolation.  \nThe main purpose is to **measure the contribution of each component** (e.g., number of pre‑training steps, masking strategy, loss function) to the overall performance. By observing how accuracy or other metrics change when a specific element is altered or omitted, researchers can:\n\n1. **Validate design decisions** – e.g., confirm that longer pre‑training or a particular masking strategy actually improves fine‑tuning results.  \n2. **Identify bottlenecks** – e.g., determine if a mismatch between pre‑training and fine‑tuning (such as the use of `[MASK]`) hurts performance.  \n3. **Guide future work** – by pinpointing which parts are most critical, researchers can focus on improving those areas.\n\nIn short, ablation studies help dissect a model’s behavior and justify architectural or training choices.'

# %%
naive_chunk_vectorstore = Chroma.from_documents(naive_chunks, embedding=embed_model)
naive_chunk_retriever = naive_chunk_vectorstore.as_retriever(search_kwargs={"k" : 5})
naive_rag_chain = (
    {"context" : naive_chunk_retriever, "question" : RunnablePassthrough()}
    | rag_prompt
    | llm
    | StrOutputParser()
)

# %%
#Ask Question
response = naive_rag_chain.invoke("Describe the Feature-based Approach with BERT?")
print(response)
# Out:
# **Feature‑based approach with BERT**
#
# The feature‑based approach uses a pre‑trained BERT model only as a *feature extractor* – the network is **not fine‑tuned** on the downstream task.  The steps are:
#
# | Step | What happens | Why it matters |
# |------|------------|---------------|
# | **1. Load a frozen BERT model** | The pre‑trained weights (from the *base* or *large* checkpoint) are loaded and kept fixed. | Keeps the rich, unsupervised language representation intact. |
# | **2. Extract token‑level activations** | For each token in the input sentence, the hidden representations from one or more of BERT’s layers are taken.  In the paper the best result was obtained by **concatenating the last four hidden layers** (each 768 d). | Captures both lower‑level lexical cues (earlier layers) and higher‑level contextual signals (later layers). |
# ...

# %%
naive_rag_chain.invoke("What is SQuADv2.0?")
# Out:
# 'SQuAD\u202fv2.0 is the second version of the Stanford Question‑Answering Dataset (SQuAD). It builds on the original SQuAD\u202f1.1 benchmark by adding a new class of questions: those that cannot be answered with a span from the provided paragraph. In SQuAD\u202f2.0, a question may be “unanswerable” and the model must learn to predict a “no‑answer” span (typically represented by the [CLS] token in BERT). This makes the task more realistic and challenging, requiring systems to distinguish between answerable and unanswerable queries while still extracting answer spans when they exist.'

# %%
naive_rag_chain.invoke("What is the purpose of Ablation Studies?")
# Out:
# 'Ablation studies are systematic experiments in which researchers remove or alter specific components, settings, or strategies of a model to see how those changes affect performance. Their main purposes are:\n\n1. **Identify the contribution of individual parts** – By turning off or replacing a component (e.g., a masking strategy, number of training steps, or a particular loss term), researchers can quantify how much that part matters for the overall result.\n\n2. **Understand trade‑offs and convergence behavior** – For example, the BERT paper’s ablation over training steps shows whether longer pre‑training yields more accuracy, and whether masked language modeling converges slower than left‑to‑right training.\n\n3. **Reduce mismatch between pre‑training and fine‑tuning** – Ablations on masking strategies demonstrate how different masking rates (MASK, SAME, RND) impact downstream tasks like MNLI and NER, helping to choose a strategy that best bridges the gap between pre‑training obje
# ...
